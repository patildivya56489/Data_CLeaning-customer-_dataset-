# %% [markdown]
# #check for any duplicate and if any remove them

# %%
import pandas as pd

# %%
# import dataset
df = pd.read_excel("datasets/ccl.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 2
#       1 # import dataset
# ----> 2 df = pd.read_excel("datasets/ccl.xlsx")
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
# ...

# %%
df.head()
# Out:
#    CustomerID First_Name Last_Name  Phone_Number  \
# 0        1001      Frodo   Baggins  123-545-5421
# 1        1002       Abed     Nadir  123/643/9775
# 2        1003     Walter    /White    7066950392
# 3        1004     Dwight   Schrute  123-543-2345
# 4        1005        Jon      Snow  876|678|3469
#
#                                  Address Paying Customer Do_Not_Contact  \
# 0                  123 Shire Lane, Shire             Yes             No
# 1                    93 West Main Street              No            Yes
# 2                     298 Drugs Driveway               N            NaN
# 3  980 Paper Avenue, Pennsylvania, 18503             Yes              Y
# 4                       123 Dragons Road               Y             No
#
#    Not_Useful_Column
# 0               True
# 1              False
# 2               True
# 3               True
# 4               True

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.read_excel("datasets/ccl.xlsx")

# %%
fd = df.duplicated()

# %%
fd
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20     True
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df[fd]
# Out:
#     CustomerID First_Name  Last_Name  Phone_Number  \
# 20        1020     Anakin  Skywalker  876|678|3469
#
#                         Address Paying Customer Do_Not_Contact  \
# 20  910 Tatooine Road, Tatooine             Yes              N
#
#     Not_Useful_Column
# 20               True

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White    7066950392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee           NaN
# 11        1012      Harry    ...Potter    7066950392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876|678|3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123/643/9775
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Step 2

# %%
df.columns
# Out:
# Index(['CustomerID', 'First_Name', 'Last_Name', 'Phone_Number', 'Address',
#        'Paying Customer', 'Do_Not_Contact', 'Not_Useful_Column'],
#       dtype='object')

# %%
df['Last_Name']
# Out:
# 0         Baggins
# 1           Nadir
# 2          /White
# 3         Schrute
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         Gamgee
# 11      ...Potter
# 12         Draper
# 13          Knope
# 14    Flenderson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: object

# %%
df['Phone_Number']
# Out:
# 0     123-545-5421
# 1     123/643/9775
# 2       7066950392
# 3     123-543-2345
# 4     876|678|3469
# 5     304-762-2467
# 6              NaN
# 7     876|678|3469
# 8              N/a
# 9     123-545-5421
# 10             NaN
# 11      7066950392
# 12    123-543-2345
# 13    876|678|3469
# 14    304-762-2467
# 15    123-545-5421
# 16    123/643/9775
# 17      7066950392
# 18             N/a
# 19    876|678|3469
# Name: Phone_Number, dtype: object

# %%
# steps to make all numbers in the phone number column to be of same length and formate
# step1 - replace all the unwanted charcters to empty string("")

# %%
df['Phone_Number']=df['Phone_Number'].apply(lambda x : str(x))

# %%
df['Phone_Number'] = df['Phone_Number'].str.replace("[^0-9]","",regex=True)

# %%
df['Phone_Number']=df['Phone_Number'].apply(lambda x:x[0:3]+"-"+x[3:6]+"-"+x[6:10])

# %% [markdown]
# ### abc-def-ghij

# %% [markdown]
# #### apply() => Apply is a Pandas function which will apply specified functionality to each value of series

# %%
df['Phone_Number']
# Out:
# 0     123-545-5421
# 1     123-643-9775
# 2     706-695-0392
# 3     123-543-2345
# 4     876-678-3469
# 5     304-762-2467
# 6               --
# 7     876-678-3469
# 8               --
# 9     123-545-5421
# 10              --
# 11    706-695-0392
# 12    123-543-2345
# 13    876-678-3469
# 14    304-762-2467
# 15    123-545-5421
# 16    123-643-9775
# 17    706-695-0392
# 18              --
# 19    876-678-3469
# Name: Phone_Number, dtype: object

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123-643-9775
# 2         1003     Walter       /White  706-695-0392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876-678-3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger            --
# 7         1008   Sherlock       Holmes  876-678-3469
# 8         1009    Gandalf          NaN            --
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee            --
# 11        1012      Harry    ...Potter  706-695-0392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876-678-3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123-643-9775
# ...

# %%
# address
df.columns
# Out:
# Index(['CustomerID', 'First_Name', 'Last_Name', 'Phone_Number', 'Address',
#        'Paying Customer', 'Do_Not_Contact', 'Not_Useful_Column'],
#       dtype='object')

# %%
# address
df['Address'].str.split(',')
# Out:
# 0                      [123 Shire Lane,  Shire]
# 1                         [93 West Main Street]
# 2                          [298 Drugs Driveway]
# 3     [980 Paper Avenue,  Pennsylvania,  18503]
# 4                            [123 Dragons Road]
# 5                            [768 City Parkway]
# 6                           [1209 South Street]
# 7                               [98 Clue Drive]
# 8                            [123 Middle Earth]
# 9                 [25th Main Street,  New York]
# 10                     [612 Shire Lane,  Shire]
# 11                       [2394 Hogwarts Avenue]
# 12                           [2039 Main Street]
# 13                           [343 City Parkway]
# 14                              [214 HR Avenue]
# 15                       [2395 Hogwarts Avenue]
# 16            [121 Paper Avenue,  Pennsylvania]
# 17                            [3498 Super Lane]
# 18                                        [N/a]
# 19               [910 Tatooine Road,  Tatooine]
# ...

# %%
df['Address'].str.split(',',expand=True)
# Out:
#                        0              1       2
# 0         123 Shire Lane          Shire    None
# 1    93 West Main Street           None    None
# 2     298 Drugs Driveway           None    None
# 3       980 Paper Avenue   Pennsylvania   18503
# 4       123 Dragons Road           None    None
# 5       768 City Parkway           None    None
# 6      1209 South Street           None    None
# 7          98 Clue Drive           None    None
# 8       123 Middle Earth           None    None
# 9       25th Main Street       New York    None
# 10        612 Shire Lane          Shire    None
# 11  2394 Hogwarts Avenue           None    None
# 12      2039 Main Street           None    None
# 13      343 City Parkway           None    None
# 14         214 HR Avenue           None    None
# 15  2395 Hogwarts Avenue           None    None
# 16      121 Paper Avenue   Pennsylvania    None
# 17       3498 Super Lane           None    None
# 18                   N/a           None    None
# ...

# %%
# spliting address into 3 sep cols
df[['street_Addres','City','Pin_Code']] = df['Address'].str.split(',',expand=True)

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123-643-9775
# 2         1003     Walter       /White  706-695-0392
# 3         1004     Dwight      Schrute  123-543-2345
# 4         1005        Jon         Snow  876-678-3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger            --
# 7         1008   Sherlock       Holmes  876-678-3469
# 8         1009    Gandalf          NaN            --
# 9         1010      Peter       Parker  123-545-5421
# 10        1011    Samwise       Gamgee            --
# 11        1012      Harry    ...Potter  706-695-0392
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie        Knope  876-678-3469
# 14        1015       Toby  Flenderson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017   Michael         Scott  123-643-9775
# ...

# %%
df['Paying Customer']
# Out:
# 0     Yes
# 1      No
# 2       N
# 3     Yes
# 4       Y
# 5     Yes
# 6      No
# 7       N
# 8     Yes
# 9     Yes
# 10    Yes
# 11      Y
# 12    Yes
# 13    Yes
# 14      N
# 15     No
# 16    Yes
# 17      Y
# 18    N/a
# 19    Yes
# Name: Paying Customer, dtype: object

# %%
df['Paying Customer'].str.replace('yes','y')
# Out:
# 0     Yes
# 1      No
# 2       N
# 3     Yes
# 4       Y
# 5     Yes
# 6      No
# 7       N
# 8     Yes
# 9     Yes
# 10    Yes
# 11      Y
# 12    Yes
# 13    Yes
# 14      N
# 15     No
# 16    Yes
# 17      Y
# 18    N/a
# 19    Yes
# Name: Paying Customer, dtype: object

# %%
df['Paying Customer']=df['Paying Customer'].str.replace('yes','y')

# %%
df['Paying Customer']=df['Paying Customer'].str.replace('No','N')

# %%
df['Paying Customer']
# Out:
# 0     Yes
# 1       N
# 2       N
# 3     Yes
# 4       Y
# 5     Yes
# 6       N
# 7       N
# 8     Yes
# 9     Yes
# 10    Yes
# 11      Y
# 12    Yes
# 13    Yes
# 14      N
# 15      N
# 16    Yes
# 17      Y
# 18    N/a
# 19    Yes
# Name: Paying Customer, dtype: object

# %%
df.columns
# Out:
# Index(['CustomerID', 'First_Name', 'Last_Name', 'Phone_Number', 'Address',
#        'Paying Customer', 'Do_Not_Contact', 'Not_Useful_Column',
#        'street_Addres', 'City', 'Pin_Code'],
#       dtype='object')

# %%
df['DO_Not Contact']=df['Paying Customer'].str.replace('yes','y')
df['DO_Not Contact']=df['Paying Customer'].str.replace('No','N')

# %%
df['DO_Not Contact']
# Out:
# 0     Yes
# 1       N
# 2       N
# 3     Yes
# 4       Y
# 5     Yes
# 6       N
# 7       N
# 8     Yes
# 9     Yes
# 10    Yes
# 11      Y
# 12    Yes
# 13    Yes
# 14      N
# 15      N
# 16    Yes
# 17      Y
# 18    N/a
# 19    Yes
# Name: DO_Not Contact, dtype: object

# %%
# remove columns
df.drop(columns=['Not_Useful_Column','Address'],inplace=True)

# %%
fullname = "virat,kholi"
fullname.split(',')
# Out:
# ['virat', 'kholi']

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo      Baggins  123-545-5421             Yes
# 1         1002       Abed        Nadir  123-643-9775               N
# 2         1003     Walter       /White  706-695-0392               N
# 3         1004     Dwight      Schrute  123-543-2345             Yes
# 4         1005        Jon         Snow  876-678-3469               Y
# 5         1006        Ron      Swanson  304-762-2467             Yes
# 6         1007       Jeff       Winger            --               N
# 7         1008   Sherlock       Holmes  876-678-3469               N
# 8         1009    Gandalf          NaN            --             Yes
# 9         1010      Peter       Parker  123-545-5421             Yes
# 10        1011    Samwise       Gamgee            --             Yes
# 11        1012      Harry    ...Potter  706-695-0392               Y
# 12        1013        Don       Draper  123-543-2345             Yes
# ...

# %% [markdown]
# ### Dealing with null values

# %%
df.replace('N/a','',inplace=True)
df.replace('NaN','',inplace=True)

# %%
df.replace('--','',inplace=True)

# %%
import numpy as np

# N/a , None = > null value
type('N/a')
# Out:
# str

# %%
df.fillna('',inplace=True)

# %%
for i in df.index:
   if df.loc[i,'Do_Not_Contact'] == "Y" or df.loc[i,'Phone_Number'] == "Y":
      df.drop(i,inplace=True)

# %%
df
# Out:
#     CustomerID First_Name    Last_Name  Phone_Number Paying Customer  \
# 0         1001      Frodo      Baggins  123-545-5421             Yes
# 1         1002       Abed        Nadir  123-643-9775               N
# 2         1003     Walter       /White  706-695-0392               N
# 4         1005        Jon         Snow  876-678-3469               Y
# 5         1006        Ron      Swanson  304-762-2467             Yes
# 6         1007       Jeff       Winger                             N
# 7         1008   Sherlock       Holmes  876-678-3469               N
# 8         1009    Gandalf                                        Yes
# 9         1010      Peter       Parker  123-545-5421             Yes
# 10        1011    Samwise       Gamgee                           Yes
# 11        1012      Harry    ...Potter  706-695-0392               Y
# 12        1013        Don       Draper  123-543-2345             Yes
# 13        1014     Leslie        Knope  876-678-3469             Yes
# ...

# %%
df['Do_Not_Contact']
# Out:
# 0      No
# 1     Yes
# 2
# 4      No
# 5     Yes
# 6      No
# 7      No
# 8
# 9      No
# 10     No
# 11
# 12      N
# 13     No
# 14     No
# 15      N
# 16     No
# 17
# 18    Yes
# 19      N
# Name: Do_Not_Contact, dtype: object

# %%
for i in df.index:
   if df.loc[i,'Do_Not_Contact'] == "Y" or df.loc[i,'Phone_Number'] == "Y":
      df.drop(i,inplace=True)

# %%
df.reset_index(inplace=True,drop=True)

# %%
df

# %%
df.to_csv('Datasets\ccl2.xlsx',index=False)
